# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in d:\datascience\.venv\lib\site-packages (0.2.66)
# Requirement already satisfied: websockets>=13.0 in d:\datascience\.venv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\datascience\.venv\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: pytz>=2022.5 in d:\datascience\.venv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: numpy>=1.16.5 in d:\datascience\.venv\lib\site-packages (from yfinance) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in d:\datascience\.venv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: requests>=2.31 in d:\datascience\.venv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: curl_cffi>=0.7 in d:\datascience\.venv\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: frozendict>=2.3.4 in d:\datascience\.venv\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\datascience\.venv\lib\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pandas>=1.3.0 in d:\datascience\.venv\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: protobuf>=3.19.0 in d:\datascience\.venv\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: peewee>=3.16.2 in d:\datascience\.venv\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: soupsieve>1.2 in d:\datascience\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\datascience\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in d:\datascience\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in d:\datascience\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in d:\datascience\.venv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\datascience\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\datascience\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\datascience\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\datascience\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\datascience\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\datascience\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'D:\Datascience\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: bs4 in d:\datascience\.venv\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\datascience\.venv\lib\site-packages (from bs4) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in d:\datascience\.venv\lib\site-packages (from beautifulsoup4->bs4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\datascience\.venv\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'D:\Datascience\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: nbformat in d:\datascience\.venv\lib\site-packages (5.10.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\datascience\.venv\lib\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in d:\datascience\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: jsonschema>=2.6 in d:\datascience\.venv\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\datascience\.venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: referencing>=0.28.4 in d:\datascience\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\datascience\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\datascience\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\datascience\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: platformdirs>=2.5 in d:\datascience\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: pywin32>=300 in d:\datascience\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\datascience\.venv\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'D:\Datascience\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in d:\datascience\.venv\lib\site-packages (3.9.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\datascience\.venv\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\datascience\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: pillow>=8 in d:\datascience\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\datascience\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: numpy>=1.23 in d:\datascience\.venv\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\datascience\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in d:\datascience\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\datascience\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in d:\datascience\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\datascience\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in d:\datascience\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in d:\datascience\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'D:\Datascience\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# The make_graph function has been modified to use Matplotlib for static graphs. Earlier, it used Plotly to generate interactive dashboards, which caused issues when uploading the notebook in the MARK assignment submission.



import matplotlib.pyplot as plt

def make_graph(stock_data, revenue_data, stock):
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']

    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    # Stock price
    axes[0].plot(pd.to_datetime(stock_data_specific.Date), stock_data_specific.Close.astype("float"), label="Share Price", color="blue")
    axes[0].set_ylabel("Price ($US)")
    axes[0].set_title(f"{stock} - Historical Share Price")

    # Revenue
    axes[1].plot(pd.to_datetime(revenue_data_specific.Date), revenue_data_specific.Revenue.astype("float"), label="Revenue", color="green")
    axes[1].set_ylabel("Revenue ($US Millions)")
    axes[1].set_xlabel("Date")
    axes[1].set_title(f"{stock} - Historical Revenue")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Using the `Ticker` function enter the ticker symbol of the stock we want to extract data on to create a ticker object. The stock is Tesla and its ticker symbol is `TSLA`.

# %%
tesla = yf.Ticker('TSLA')

# %% [markdown]
# Using the ticker object and the function `history` extract stock information and save it in a dataframe named `tesla_data`. Set the `period` parameter to ` "max" ` so we get information for the maximum amount of time.

# %%
tesla_data = tesla.history(period = "max")

# %% [markdown]
# **Reset the index** using the `reset_index(inplace=True)` function on the tesla_data DataFrame and display the first five rows of the `tesla_data` dataframe using the `head` function. Take a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# Use the `requests` library to download the webpage https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm Save the text of the response as a variable named `html_data`.

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0"
}

html_data = requests.get("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm", headers=headers).text

# %% [markdown]
# Parse the html data using `beautiful_soup` using parser i.e `html5lib` or `html.parser`.

# %%
beautiful_soup = BeautifulSoup(html_data, "html.parser")

# %% [markdown]
# Using BeautifulSoup or the read_html function extract the table with Tesla Revenue and store it into a dataframe named tesla_revenue. The dataframe should have columns Date and Revenue.

# %%
tesla_data = beautiful_soup.find("table", {"class": "historical_data_table"})
rows = []
for tr in tesla_data.find_all('tr'):
    cols = tr.find_all("td")
    cols = [c.text.strip() for c in cols]
    if len(cols) == 2:      # keep only Date + Revenue rows
        rows.append(cols)

tesla_revenue = pd.DataFrame(rows, columns=["Data","Revenue"])
tesla_revenue
print(tesla_data is not None)
# Out:
# True

# %% [markdown]
# Execute the following line to remove the comma and dollar sign from the `Revenue` column.

# %%
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"",regex=True)

# %% [markdown]
# Execute the following lines to remove an null or empty strings in the Revenue column.

# %%
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# %% [markdown]
# Display the last 5 row of the `tesla_revenue` dataframe using the `tail` function. Take a screenshot of the results.

# %%
tesla_revenue.tail(5)
# Out:
#     Data Revenue
# 8   2013    2013
# 9   2012     413
# 10  2011     204
# 11  2010     117
# 12  2009     112

# %% [markdown]
# Question 3: Use yfinance to Extract Stock Data¶
#
# Using the Ticker function enter the ticker symbol of the stock we want to extract data on to create a ticker object. The stock is GameStop and its ticker symbol is GME.

# %%
gme = yf.Ticker("GME")

# %% [markdown]
# Using the ticker object and the function history extract stock information and save it in a dataframe named gme_data. Set the period parameter to "max" so we get information for the maximum amount of time.

# %%
gme_data = gme.history(period="max")

# %% [markdown]
# Reset the index using the reset_index(inplace=True) function on the gme_data DataFrame and display the first five rows of the gme_data dataframe using the head function. Take a screenshot of the results and code from the beginning of Question 3 to the results below.

# %%
gme_data.reset_index(inplace=True)

# %% [markdown]
# Question 4: Use Webscraping to Extract GME Revenue Data
#
# Use the requests library to download the webpage https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html. Save the text of the response as a variable named html_data_2

# %%
html_data_2 = requests.get("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html").text

# %% [markdown]
# Parse the html data using `beautiful_soup` using parser i.e `html5lib` or `html.parser`.

# %%
beautiful_soup_2 = BeautifulSoup(html_data_2, "html.parser")

# %% [markdown]
# Using BeautifulSoup or the read_html function extract the table with GameStop Revenue and store it into a dataframe named gme_revenue. The dataframe should have columns Date and Revenue. Make sure the comma and dollar sign is removed from the Revenue column.
#
#     Note: Use the method similar to what you did in question 2.

# %%
gme_data = beautiful_soup_2.find("table")

rows = []
for tr in gme_data.find_all("tr"):
    tr
    cols = tr.find_all("td")
    cols = [c.text.strip() for c in cols]
    if len(cols) == 2:      # keep only Date + Revenue rows
        rows.append(cols)

gme_revenue = pd.DataFrame(rows, columns=["Data","Revenue"])
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\$',"",regex=True)
gme_revenue
# Out:
#     Data Revenue
# 0   2020    6466
# 1   2019    8285
# 2   2018    8547
# 3   2017    7965
# 4   2016    9364
# 5   2015    9296
# 6   2014    9040
# 7   2013    8887
# 8   2012    9551
# 9   2011    9474
# 10  2010    9078
# 11  2009    8806
# 12  2008    7094
# 13  2007    5319
# 14  2006    3092
# 15  2005    1843

# %% [markdown]
# Remove the comma and dollar sign, an null or empty strings from the Revenue column.

# %%
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\$',"",regex=True)

# %% [markdown]
# Display the last five rows of the `gme_revenue` dataframe using the `tail` function. Take a screenshot of the results.

# %%
gme_revenue.head()
# Out:
#    Data Revenue
# 0  2020    6466
# 1  2019    8285
# 2  2018    8547
# 3  2017    7965
# 4  2016    9364

# %% [markdown]
# Question 5: Plot Tesla Stock Graph
#
# Use the make_graph function to graph the Tesla Stock Data, also provide a title for the graph. Note the graph will only show data upto June 2021.

# %%
# The make_graph function has been modified to use Matplotlib for static graphs. Earlier, it used Plotly to generate interactive dashboards, which caused issues when uploading the notebook in the MARK assignment submission.



import matplotlib.pyplot as plt


def make_graph(stock_data, revenue_data, stock):
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']

    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    # Stock price
    axes[0].plot(pd.to_datetime(stock_data_specific.Date), stock_data_specific.Close.astype("float"), label="Share Price", color="blue")
    axes[0].set_ylabel("Price ($US)")
    axes[0].set_title(f"{stock} - Historical Share Price")

    # Revenue
    axes[1].plot(pd.to_datetime(revenue_data_specific.Date), revenue_data_specific.Revenue.astype("float"), label="Revenue", color="green")
    axes[1].set_ylabel("Revenue ($US Millions)")
    axes[1].set_xlabel("Date")
    axes[1].set_title(f"{stock} - Historical Revenue")

    plt.tight_layout()
    plt.show()

make_graph(tesla_data, tesla_revenue, 'Tesla')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 28
#      25     plt.tight_layout()
#      26     plt.show()
# ---> 28 make_graph(tesla_data, tesla_revenue, 'Tesla')
#
# Cell In[62], line 9, in make_graph(stock_data, revenue_data, stock)
#       8 def make_graph(stock_data, revenue_data, stock):
# ----> 9     stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
#      10     revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
#      12     fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'str'

# %% [markdown]
# Question 6: Plot GameStop Stock Graph
#
# Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph. The structure to call the make_graph function is make_graph(gme_data, gme_revenue, 'GameStop'). Note the graph will only show data upto June 2021.

# %%
make_graph(gme_data, gme_revenue, 'GameStop')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 make_graph(gme_data, gme_revenue, 'GameStop')
#
# Cell In[62], line 9, in make_graph(stock_data, revenue_data, stock)
#       8 def make_graph(stock_data, revenue_data, stock):
# ----> 9     stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
#      10     revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
#      12     fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'str'
